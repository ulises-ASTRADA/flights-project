# %%
from datetime import datetime
import requests
import pandas as pd
import psycopg2

# %%
# Define the constants to connect to the API
ACCESS_KEY = '13824a221d87297fe2e6bc3c8ee20a94'
BASE_URL = 'https://api.aviationstack.com/v1/'

def fetch_flights_data():
    # Fetch flight data from the API
    api_result = requests.get(f'{BASE_URL}flights?access_key={ACCESS_KEY}&limit=100&flight_status=active')

    flights = api_result.json()

    # Access the columns we are interested in
    flights_data = flights['data']

    # Create an empty list to save the records
    collected_data = []

    for flight in flights_data:
        flight_info = {
            'flight_date': flight['flight_date'],
            'flight_status': flight['flight_status'],
            'departure_airport': flight['departure']['airport'],
            'departure_timezone': flight['departure']['timezone'],
            'arrival_airport': flight['arrival']['airport'],
            'arrival_timezone': flight['arrival']['timezone'],
            'arrival_terminal': flight['arrival'].get('terminal', None),  # Handle missing terminal values
            'airline_name': flight['airline']['name'],
            'flight_number': flight['flight']['number']
        }

        collected_data.append(flight_info)

    # Convert the collected data to a DataFrame
    collected_data_to_df = pd.DataFrame(collected_data)

    # Print the number of rows fetched
    number_of_rows = len(collected_data_to_df)
    print(f'Data fetched containing {number_of_rows} rows')

    # Return the collected data DataFrame
    return collected_data_to_df
fetch_flights_data()
# Out:
# Data fetched containing 100 rows
#    flight_date flight_status              departure_airport  \
# 0   2024-10-07        active            Perth International
# 1   2024-10-07        active                 Haneda Airport
# 2   2024-10-07        active         Auckland International
# 3   2024-10-07        active     Christchurch International
# 4   2024-10-07        active     Christchurch International
# ..         ...           ...                            ...
# 95  2024-10-07        active       Ngurah Rai International
# 96  2024-10-07        active              Zia International
# 97  2024-10-07        active  Shanghai Pudong International
# 98  2024-10-07        active         Tashkent International
# 99  2024-10-07        active                       Roschino
#
#     departure_timezone                            arrival_airport  \
# 0      Australia/Perth  Kuala Lumpur International Airport (klia)
# 1           Asia/Tokyo                           Singapore Changi
# 2     Pacific/Auckland             Sydney Kingsford Smith Airport
# 3     Pacific/Auckland            Melbourne - Tullamarine Airport
# 4     Pacific/Auckland            Melbourne - Tullamarine Airport
# ..                 ...                                        ...
# 95       Asia/Makassar                            Seoul (Incheon)
# 96          Asia/Dhaka                  King Khaled International
# 97       Asia/Shanghai                                Vladivostok
# 98       Asia/Tashkent                                Krasnojarsk
# 99  Asia/Yekaterinburg                                Krasnojarsk
#
#        arrival_timezone arrival_terminal               airline_name  \
# 0     Asia/Kuala_Lumpur                1                   Oman Air
# 1        Asia/Singapore                1                   AlphaSky
# 2      Australia/Sydney                1                     Qantas
# 3   Australia/Melbourne                2            Air New Zealand
# 4   Australia/Melbourne                2            United Airlines
# ..                  ...              ...                        ...
# 95           Asia/Seoul                2           Garuda Indonesia
# 96          Asia/Riyadh                1  Biman Bangladesh Airlines
# 97     Asia/Vladivostok                A           Rossiya Airlines
# 98     Asia/Krasnoyarsk                1           Rossiya Airlines
# 99     Asia/Krasnoyarsk                1           Rossiya Airlines
#
#    flight_number
# 0           5559
# 1           7349
# 2            140
# 3            211
# 4           6795
# ..           ...
# 95          9964
# 96           339
# 97          6648
# 98          6726
# 99          6788
#
# [100 rows x 9 columns]

# %%
print(collected_data_to_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 print(collected_data_to_df)
#
# NameError: name 'collected_data_to_df' is not defined

# %%
    conn = psycopg2.connect(
        dbname="airflow",
        user="airflow",
        password="airflow",
        host="localhost",
        port="5434"
    )
    cursor = conn.cursor()
    
    # Here we create the table
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS testdata (
        flight_date DATE,
        flight_status VARCHAR,
        departure_airport VARCHAR,
        departure_timezone VARCHAR,
        arrival_airport VARCHAR,
        arrival_timezone VARCHAR,
        arrival_terminal VARCHAR,
        airline_name VARCHAR,
        flight_number TEXT DEFAULT 'UNKNOWN'
    );
    """)

    conn.commit()


    for flight, value in collected_data_to_df.iterrows():
        cursor.execute(
            "INSERT INTO testdata (flight_date, flight_status, departure_airport, departure_timezone, arrival_airport, arrival_timezone, arrival_terminal, airline_name, flight_number) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)",
            (value['flight_date'], value['flight_status'], value['departure_airport'], value['departure_timezone'], value['arrival_airport'], value['arrival_timezone'], value['arrival_terminal'], value['airline_name'], value['flight_number'])
        )
    
    cursor.close()
    conn.close()

    print("Data inserted successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 28
#      11 cursor.execute("""
#      12 CREATE TABLE IF NOT EXISTS testdata (
#      13     flight_date DATE,
#    (...)
#      22 );
#      23 """)
#      25 conn.commit()
# ---> 28 for flight, value in collected_data_to_df.iterrows():
#      29     cursor.execute(
#      30         "INSERT INTO testdata (flight_date, flight_status, departure_airport, departure_timezone, arrival_airport, arrival_timezone, arrival_terminal, airline_name, flight_number) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)",
#      31         (value['flight_date'], value['flight_status'], value['departure_airport'], value['departure_timezone'], value['arrival_airport'], value['arrival_timezone'], value['arrival_terminal'], value['airline_name'], value['flight_number'])
#      32     )
#      34 cursor.close()
#
# NameError: name 'collected_data_to_df' is not defined
